# %% [markdown]
# <a href="https://colab.research.google.com/github/emirhneks/YapayZekaVeMakineOgrenmesi11/blob/main/Ders8/Ders8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([10, 0, 0, 10, 0, 0, 10])
y = np.array([10, 10, 5, 5, 5, 0, 0])
plt.plot(x, y)
plt.title("E Harfi")
plt.ylabel("Y Ekseni")
plt.xlabel("X Ekseni")
plt.show()
